# %%
import parsers

# %%
parsers.grants.print_table?
# Out:
# Signature: parsers.grants.print_table(grants, print=<built-in function print>)
# Docstring: <no docstring>
# File:      ~/sissa/site/sissa-site/parsers/grants.py
# Type:      function

# %% [markdown]
# # experiments with ap parser

# %%
import re

# %%
grants={}
h2_found=0
def elaborate_ap(url,b):
    global h2_found
    if b.find_all('h2'):
        #print('found <h2>: breaking',str(b))
        h2_found+=1
        pass
    if h2_found>=2:
        return
    title=b.find('strong')
    if title is None:
        return
    title.extract()
#    if 'LISA' in str(title):
#        import pdb
#        pdb.set_trace()
    link=b.find('a')
    #check for words that indicate that it is a grant -- are they all grants?
    #res=re.search(r"€|\$|[Gg]grant|ERC|PRINN", b.__str__())
    if True: # res is not None:
        return '?',b,title,link

# %%
parsers.grants.parse(grants,'https://www.sissa.it/ap/research/projects.php',{'name':'tbody'},elaborate_ap,class_='ap')
# Out:
# <div class="block ap">
#
#
#
#
#
#
#
#
#
#  <br/>
#
# The BiD4BEST ITN will offer doctoral training in one of the most visible areas of astrophysical research,
# the formation of supermassive black holes in galaxies. A coordinated research training effort in this field
# is needed now to mobilise the community in Europe and prepare a core group of young scientists in anticipation
# of new observational data in the early/mid 2020s from future space missions with strong European involvement.
# These data will have the quality and volume to yield transformational science on the formation of black-holes
# in galaxies, as long as the necessary expertise and synergies among observation, theory and data analytics
# exist within the European astronomy community. We propose to achieve this goal by setting up a research training
# network that brings together leading scientists in observational and theoretical studies of black holes and galaxies,
# ...

# %%
grants
# Out:
# {'?': [{'class': 'ap',
#    'content': <div class="block ap">
#
#
#
#
#
#
#
#
#
#     <br/>
#
#    The BiD4BEST ITN will offer doctoral training in one of the most visible areas of astrophysical research,
#    the formation of supermassive black holes in galaxies. A coordinated research training effort in this field
#    is needed now to mobilise the community in Europe and prepare a core group of young scientists in anticipation
#    of new observational data in the early/mid 2020s from future space missions with strong European involvement.
#    These data will have the quality and volume to yield transformational science on the formation of black-holes
#    in galaxies, as long as the necessary expertise and synergies among observation, theory and data analytics
#    exist within the European astronomy community. We propose to achieve this goal by setting up a research training
# ...

# %%
html=''
def grab_html_out(x):
    global html
    html = html + str(x)
parsers.grants.print_table(grants,print=grab_html_out)
Shout(html)
# Out:
# <div class="grant_m ap_outer"><div class="grant_c"><div class="grant_title"><p><a class="grant_title_link ap" href="https://www.sissa.it/ap/research/projects.php"><strong> Big Data for Black Hole Evolution Studies </strong></a></p></div><div class="block ap">
#
#
#
#
#
#
#
#
#
#  <br/>
#
# The BiD4BEST ITN will offer doctoral training in one of the most visible areas of astrophysical research,
# the formation of supermassive black holes in galaxies. A coordinated research training effort in this field
# is needed now to mobilise the community in Europe and prepare a core group of young scientists in anticipation
# of new observational data in the early/mid 2020s from future space missions with strong European involvement.
# These data will have the quality and volume to yield transformational science on the formation of black-holes
# in galaxies, as long as the necessary expertise and synergies among observation, theory and data analytics
# ...

# %% [markdown]
# # experiments with css

# %%
with open('parsers/alumni.pickle', 'rb') as inp:
    alumni=parsers.common.pickle.load(inp)

# %%
with open('parsers/grants.pickle', 'rb') as inp:
    grants=parsers.common.pickle.load(inp)

# %%
class Shout(object):
    def __init__(self, text):
        self.text = text

    def _repr_html_(self):
        with open('parsers/out.css', 'r') as css:
            print(self.text)
            return '<style>'+css.read()+'</style>' + self.text

# %%
test_content=list(grants.values())[0][0]['content']

# %%
test_content.find('ul').unwrap()

# %%
grants
# Out:
# {'2018-2023': [{'class': 'sp',
#    'content': <div class="block sp">
#
#    <div class="blockText">
#
#    2018–2023
#
#    <a href="http://www.statphys.sissa.it/wordpress/?page_id=1731">Pasquale  Calabrese</a> is the PI of the ERC Consolidator Grant n. 771536. The overall budget is about 1.5 M€ (SISSA is the only beneficiary). The main goal of the project is to find and characterise new non-equilibrium states of matter guided by their entanglement content.<br/>
#    <a href="https://cordis.europa.eu/project/rcn/214671/factsheet/en">More Information</a>
#
#    </div>
#    </div>,
#    'title': '<a class="grant_title_link sp" href="https://www.statphys.sissa.it/wordpress/?page_id=4912"><div class="blockTextTitle">\nNew states of Entangled Matter Out of equilibrium (NEMO)\n</div></a>',
#    'link': None}],
#  '2019-2022': [{'class': 'sp',
#    'content': <div class="block sp">
#
#    <div class="blockText">
#
#    2019–2022
#    <ul>
# ...

# %%
isinstance?
# Out:
# Signature: isinstance(obj, class_or_tuple, /)
# Docstring:
# Return whether an object is an instance of a class or of a subclass thereof.
#
# A tuple, as in ``isinstance(x, (A, B, ...))``, may be given as the target to
# check against. This is equivalent to ``isinstance(x, A) or isinstance(x, B)
# or ...`` etc.
# Type:      builtin_function_or_method

# %%
for g in grants.values():
    for items in g:
        if isinstance(items['content'],str): continue
        ul=items['content'].find('ul')
        if ul is not None: ul.unwrap()

# %%
test_content.find('ul').unwrap()
# Out:
# <div class="block sp">
#
# <div class="blockText">
#
# 2018–2023
#
# <a href="http://www.statphys.sissa.it/wordpress/?page_id=1731">Pasquale  Calabrese</a> is the PI of the ERC Consolidator Grant n. 771536. The overall budget is about 1.5 M€ (SISSA is the only beneficiary). The main goal of the project is to find and characterise new non-equilibrium states of matter guided by their entanglement content.<br/>
# <a href="https://cordis.europa.eu/project/rcn/214671/factsheet/en">More Information</a>
#
# </div>
# </div>

# %%
html=''
parsers.alumni.print_table(alumni,print=grap_html_out)
Shout(html)
# Out:
# --------------------------------------------------------------------------
# TypeError                                Traceback (most recent call last)
# <ipython-input-63-8b4c0faf25d5> in <module>
#       1 html=''
# ----> 2 parsers.alumni.print_table(alumni,print=grap_html_out)
#       3 Shout(html)
#
# ~/sissa/site/sissa-site/parsers/alumni.py in print_table(alumni, print)
#     177             print('<tr>')
#     178             print(n['name'])
# --> 179             print('<td class="{}">{}</td>'.format(n['class'],y))
#     180             print(n['adv'])
#     181             if 'thesis' in n:
#
# <ipython-input-8-cd9a0fd12358> in grap_html_out(x)
#       2 def grap_html_out(x):
#       3     global html
# ----> 4     html = html +x
#       5 parsers.grants.print_table(grants,print=grab_html_out)
#
# TypeError: must be str, not Tag

# %%
parsers.alumni.print_table??
# Out:
# Signature: parsers.alumni.print_table(alumni, print=<built-in function print>)
# Docstring: <no docstring>
# Source:
# def print_table(alumni,print=print):
#     print('<table><thead><tr><th>Name</th><th>Year</th><th>Supervisor</th><th>Thesis</th><th>Position</th><th>Curriculum</th></tr></thead><tbody>')
#     for y in reversed(sorted(list(alumni.keys()))):
#         for n in alumni[y]:
#             print('<tr>')
#             print(n['name'])
#             print('<td class="{}">{}</td>'.format(n['class'],y))
#             print(n['adv'])
#             if 'thesis' in n:
#                 print(n['thesis'])
#             else:
#                 print('<td></td>')
#             if 'affiliation' in n:
#                 print(n['affiliation'])
#             else:
#                 print('<td></td>')
#             print('<td class="{}" >{}</td>'.format(n['class'],n['class']))
#             print('</tr>')
#     print('</tbody></table>')
# ...
